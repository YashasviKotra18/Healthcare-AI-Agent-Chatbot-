# %%
# Install required packages
# !git clone https://github.com/maszhongming/UniEval.git
# !pip install -r UniEval/requirements.txt

# !git clone https://github.com/xu1998hz/InstructScore_SEScore3.git
# !pip install -r InstructScore_SEScore3/requirements.txt

# !pip install openai pandas numpy torch transformers matplotlib seaborn evaluate sacrebleu bert-score nltk -q
# Out:
# Cloning into 'UniEval'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 91 (delta 13), reused 5 (delta 5), pack-reused 65 (from 1)
# Receiving objects: 100% (91/91), 1.97 MiB | 9.66 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Requirement already satisfied: transformers>=4.17.0.dev0 in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 1)) (4.47.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: datasets>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 3)) (3.3.1)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 5)) (3.20.3)
# Collecting rouge-score (from -r UniEval/requirements.txt (line 6))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 7)) (3.2.4)
# Collecting py7zr (from -r UniEval/requirements.txt (line 8))
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 9)) (2.5.1+cu121)
# Collecting evaluate (from -r UniEval/requirements.txt (line 10))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from -r UniEval/requirements.txt (line 11)) (3.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (0.29.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r UniEval/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (3.11.12)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score->-r UniEval/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score->-r UniEval/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/dist-packages (from py7zr->-r UniEval/requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r UniEval/requirements.txt (line 8)) (3.21.0)
# Collecting pyzstd>=0.15.9 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading pyzstd-0.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading pyppmd-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading pybcj-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading inflate64-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting brotli>=1.1.0 (from py7zr->-r UniEval/requirements.txt (line 8))
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r UniEval/requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r UniEval/requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r UniEval/requirements.txt (line 9)) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r UniEval/requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.3->-r UniEval/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->-r UniEval/requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (1.18.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r UniEval/requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r UniEval/requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.17->transformers>=4.17.0.dev0->-r UniEval/requirements.txt (line 1)) (2024.2.0)
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 2.4 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.4 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 44.2 MB/s eta 0:00:00a 0:00:01
# Downloading inflate64-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 4.7 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.3 MB/s eta 0:00:00
# Downloading pyppmd-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 7.7 MB/s eta 0:00:00
# Downloading pyzstd-0.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.7/413.7 kB 18.5 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=8ffe90161032aac9471e8f3008c1d57428de4e571bd56f5a24b7a0ac2081ec16
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: brotli, pyzstd, pyppmd, pybcj, multivolumefile, inflate64, py7zr, rouge-score, evaluate
# Successfully installed brotli-1.1.0 evaluate-0.4.3 inflate64-1.0.1 multivolumefile-0.2.3 py7zr-0.22.0 pybcj-1.0.3 pyppmd-1.1.1 pyzstd-0.16.2 rouge-score-0.1.2
# Cloning into 'InstructScore_SEScore3'...
# remote: Enumerating objects: 913, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 913 (delta 46), reused 33 (delta 15), pack-reused 833 (from 1)
# Receiving objects: 100% (913/913), 81.05 MiB | 28.32 MiB/s, done.
# Resolving deltas: 100% (685/685), done.
# Updating files: 100% (149/149), done.
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 2)) (2.5.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 4)) (3.7.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 7)) (3.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 8)) (1.26.4)
# Collecting deepspeed (from -r InstructScore_SEScore3/requirements.txt (line 10))
#   Downloading deepspeed-0.16.5.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 11)) (3.1.0)
# Collecting flask_cors (from -r InstructScore_SEScore3/requirements.txt (line 12))
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Requirement already satisfied: daal in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 13)) (2025.2.0)
# Collecting fire (from -r InstructScore_SEScore3/requirements.txt (line 14))
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 15)) (0.21.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r InstructScore_SEScore3/requirements.txt (line 16)) (4.47.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->-r InstructScore_SEScore3/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r InstructScore_SEScore3/requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->-r InstructScore_SEScore3/requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r InstructScore_SEScore3/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r InstructScore_SEScore3/requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r InstructScore_SEScore3/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r InstructScore_SEScore3/requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2.11.0a2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (75.1.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (0.29.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10)) (0.8.0)
# Collecting hjson (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10)) (1.11.1.3)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10)) (9.0.0)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.10/dist-packages (from deepspeed->-r InstructScore_SEScore3/requirements.txt (line 10)) (12.570.86)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from flask->-r InstructScore_SEScore3/requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from flask->-r InstructScore_SEScore3/requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from flask->-r InstructScore_SEScore3/requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from daal->-r InstructScore_SEScore3/requirements.txt (line 13)) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->daal->-r InstructScore_SEScore3/requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->-r InstructScore_SEScore3/requirements.txt (line 14)) (2.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r InstructScore_SEScore3/requirements.txt (line 16)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r InstructScore_SEScore3/requirements.txt (line 16)) (0.4.5)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r InstructScore_SEScore3/requirements.txt (line 7)) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r InstructScore_SEScore3/requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (2025.1.31)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r InstructScore_SEScore3/requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->-r InstructScore_SEScore3/requirements.txt (line 8)) (2024.2.0)
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 2.6 MB/s eta 0:00:00
# Building wheels for collected packages: deepspeed, fire
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.16.5-py3-none-any.whl size=1580592 sha256=c84eabee33c93e09cedcd8f87a8cf47a962057c5dd10dadc8a6a85eb16ed5f10
#   Stored in directory: /root/.cache/pip/wheels/cb/fa/e7/98efc76db11fac734a4fae8c19dd08cc24257107e132e674f6
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=f74f24e66c5ca7fcdeb8f5e5280e34076b05600261d5432902ef9bd119444a81
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built deepspeed fire
# Installing collected packages: hjson, fire, flask_cors, deepspeed
# Successfully installed deepspeed-0.16.5 fire-0.7.0 flask_cors-5.0.1 hjson-3.1.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.1 MB/s eta 0:00:00

# %%
# Import libraries
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, AutoModelForCausalLM
from openai import OpenAI
from tqdm import tqdm
import sys
import gc
import nltk
from evaluate import load
from bert_score import score
from sacrebleu import sentence_bleu
import sys
sys.path.append('/kaggle/working/UniEval/metric')

from scorer import UniEvaluator
# Setup NLTK
nltk.download('punkt', quiet=True)

# Set seaborn style
sns.set(style="whitegrid")

# Add UniEval to system path
sys.path.append('/kaggle/working/UniEval/metric')

# Kaggle-specific configurations
pd.set_option('display.max_colwidth', 50)

# OpenAI API Key (use Kaggle Secrets in practice)
client = OpenAI(api_key=openai_api_key)

# %%
# -------------------
# Section 1: Data Loading
# -------------------
def load_data(file_path="/kaggle/input/eval-data/full_medical_qa_dataset.csv"):
    """Load dataset and limit to a small sample for Kaggle compatibility."""
    df = pd.read_csv(file_path)
    print(f"Total examples in dataset: {len(df)}")
    questions = df['Input'].fillna("").tolist()
    references = df['Output'].fillna("").tolist()
    print(f"Evaluating on  these examples to compare Fine-Tuned Models")
    return questions, references, df

questions, references, df = load_data()
# Out:
# Total examples in dataset: 20
# Evaluating on  these examples to compare Fine-Tuned Models

# %%
df.head()
# Out:
#                                                Input  \
# 0  I have been told I have COPD. I have been havi...
# 1  I recently went to the ER for severe coughing ...
# 2  Hi doctor, I have candida balanoposthitis. I c...
# 3  sir, my name is deepraj naik, from goa india, ...
# 4  I have a acorn sized lump beside my left testi...
#
#                                               Output
# 0  COPD causes airway inflammation and increased ...
# 1  Headache is a known side effect of doxycycline...
# 2  Persistent red spots may indicate incomplete r...
# 3  Loss of sensation progressing from toe to knee...
# 4  This is likely an infected sebaceous cyst. Avo...

# %%
import requests

response = requests.get('https://huggingface.co', timeout=60)  # sets timeout to 60 seconds

# %%
# -------------------
# Section 2: Model Prediction Generation
# -------------------
from transformers import GenerationConfig

def generate_biomistral_predictions(questions, model_path="KarthikNimmagadda/Biomistral-Finetuned-Medical-Dataset"):
    """Generate predictions using BioMistral with a specific prompt template and generation config."""
    # Load tokenizer and model
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")
    model.eval()

    # Define the prompt template
    prompt_template = (
        "You are a compassionate and knowledgeable healthcare advisor answering medical questions. "
        "Provide helpful, empathetic, and accurate information while maintaining appropriate medical boundaries. "
        "Be clear about limitations and when professional medical consultation is necessary. "
        "Do NOT use any introductory phrases like 'hi,' 'hello,' 'thanks for your query,' etc. "
        "Deliver only condition information and recommendations without greetings, names, thank-you statements, or closing phrases. "
        "Use clear language, explain necessary terms, and avoid all filler content. "
        "Include only condition context and appropriate recommendations. "
        "Never reference individuals from training data. "
        "Keep responses between 100-150 words. "
        "Focus exclusively on medical information. "
        "Do NOT use any introductory phrases like 'hi,' 'hello,' 'thanks for your query,' etc. "
        "Deliver only condition information and recommendations without greetings, names, thank-you statements, or closing phrases. "
        "Use clear language, explain necessary terms, and avoid all filler content. "
        "Patient's Question: {question}\nDoctor's Answer:"
    )

    # Define generation configuration
    gen_config = GenerationConfig(
        max_new_tokens=300,
        temperature=0.1,
        top_p=0.9,
        repetition_penalty=1.2
    )

    # Generate predictions
    preds = []
    for q in tqdm(questions, desc="Generating BioMistral Predictions"):
        prompt = prompt_template.format(question=q.strip())
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(model.device)
        with torch.no_grad():
            output_ids = model.generate(**inputs, generation_config=gen_config)
        answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)
        if "Doctor's Answer:" in answer:
            answer = answer.split("Doctor's Answer:")[-1].strip()
        preds.append(answer)

    # Clean up to free memory
    del model, tokenizer
    torch.cuda.empty_cache()
    gc.collect()
    return preds

# %%
def generate_gpt4_predictions(questions):
    """
    Generate predictions using GPT-4 via OpenAI API.
    You are a compassionate and knowledgeable medical doctor
    
    """
    preds = []
    for q in tqdm(questions, desc="Generating GPT-4 Predictions"):
        try:
            response = client.chat.completions.create(
                model="gpt-3.5-turbo-0125",  # Using 3.5-turbo as a proxy due to API access
                messages=[{"role": "user", "content": q}],
                temperature=0.1
            )
            preds.append(response.choices[0].message.content.strip())
        except Exception as e:
            print(f"GPT-4 error on question '{q[:20]}...': {e}")
            preds.append("")
    return preds

# %%
# Generate predictions
bm_predictions = generate_biomistral_predictions(questions)
gpt4_predictions = generate_gpt4_predictions(questions)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.51M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/567 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/14.5G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# Generating BioMistral Predictions:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:   5%|▌         | 1/20 [00:23<07:32, 23.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  10%|█         | 2/20 [00:41<06:05, 20.33s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  15%|█▌        | 3/20 [00:51<04:27, 15.73s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  20%|██        | 4/20 [00:57<03:08, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  25%|██▌       | 5/20 [01:04<02:31, 10.12s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  30%|███       | 6/20 [01:14<02:20, 10.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  35%|███▌      | 7/20 [01:23<02:06,  9.73s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  40%|████      | 8/20 [01:34<01:59,  9.94s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  45%|████▌     | 9/20 [01:48<02:03, 11.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  50%|█████     | 10/20 [01:59<01:52, 11.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  55%|█████▌    | 11/20 [02:08<01:34, 10.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  60%|██████    | 12/20 [02:21<01:30, 11.28s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  65%|██████▌   | 13/20 [02:35<01:24, 12.05s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  70%|███████   | 14/20 [02:44<01:07, 11.30s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  75%|███████▌  | 15/20 [02:52<00:50, 10.10s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  80%|████████  | 16/20 [03:01<00:39,  9.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  85%|████████▌ | 17/20 [03:17<00:35, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  90%|█████████ | 18/20 [03:25<00:20, 10.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  95%|█████████▌| 19/20 [03:37<00:11, 11.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions: 100%|██████████| 20/20 [03:51<00:00, 11.59s/it]
# Generating GPT-4 Predictions: 100%|██████████| 20/20 [00:33<00:00,  1.68s/it]

# %%
# Let's have a look at one example output
for i in range(3):
    print("Question:", questions[i] )
    print("------\n")

    print("BioMistral Answer:", bm_predictions[i])
    print("------\n")

    print("Reference Answer:", df['Output'].iloc[i])
    print("------\n")
# Out:
# Question: I have been told I have COPD. I have been having problems for 2 months. I am now having trouble coughing until I throw up, I am on Advair, Albuterol, Sinus medicine, and Mucus relief. Is there anything that will stop this coughing. My bronchial tubes are very sore.
# ------
#
# BioMistral Answer: Hi, thanks for posting your question here. I understand you to be suffering from chronic obstructive pulmonary disease (COPD). It is an inflammatory lung disorder characterized by airflow obstruction in the lungs. The symptoms of COPD include shortness of breath, cough, wheezing, chest tightness, and excessive mucous production. There are several medications available to treat COPD. These include bronchodilators such as albuterol, ipratropium bromide, tiotropium, formoterol fumarate, salmeterol xinafoate, and fluticasone propionate. Anticholinergic agents such as glycopyrrolate and aclidinium bromide can also help relieve symptoms. Oral corticosteroids may also be prescribed if there is severe inflammation present. Additionally, smoking cessation is one of the most important steps towards managing COPD. Avoiding exposure to smoke and other irritants can also help reduce symptoms. Hope this helps. Let me know if you have further queries.
# ------
#
# Reference Answer: COPD causes airway inflammation and increased sputum production, worsened by infection. Antibiotics may be needed if infection is present. Enroll in a pulmonary rehabilitation program for chest physiotherapy and deep breathing exercises to clear secretions. Consider adding an expectorant like N-acetylcysteine (NAC) or guaifenesin.
# ------
#
# Question: I recently went to the ER for severe coughing due to mountain cedar which triggered my asthma. I was given a breathing treatment and Doxycycline Hyclate 100mg cap. Every since I started taking the antibiotic I have had severe headaches with a lot of pressure. I have had only about 5 hrs of sleep in 4 days due to the pressure and headache worsening when I lay down. Any suggestions why I'm getting like this?
# ------
#
# BioMistral Answer: Hi, thanks for posting your question here. It seems that you have been suffering from an acute upper respiratory tract infection (URTI) caused by allergic reaction to mountain cedars. The symptoms include sneezing, runny nose, itchy eyes, sore throat, fever, cough, and congestion. These symptoms can be treated with over-the-counter medications such as antihistamines, decongestants, nasal sprays, and pain relievers. However, if these symptoms persist for more than two weeks, then you should consult your doctor for further evaluation. Regarding your headache, it could be related to the URTI or stress. If the headache continues even after treating the URTI, then you may need to see a neurologist for further evaluation. Hope this helps. Let me know if you have any other queries.
# ------
#
# Reference Answer: Headache is a known side effect of doxycycline, often resolving after discontinuation. Reduce salt intake to lessen pressure. If symptoms persist, consult your doctor to adjust the antibiotic.
# ------
#
# Question: Hi doctor, I have candida balanoposthitis. I consulted a doctor, and he gave me Glospor DS 200 mg for a week with Livafin ointment. But still, I am having red spots on the penis. My penis is uncircumcised. Please provide your suggestion.
# ------
#
# BioMistral Answer: Hello, thanks for posting your question here. Candida infection can be treated by using antifungal creams such as Clotrimazole, Miconazole, Econazole, Ketoconazole, and oral tablets such as Fluconazole, Terbinafine, Diflucan, etc. If you are not getting relief after applying these medicines, then you should visit your local hospital and get blood tests done to rule out other infections.
# ------
#
# Reference Answer: Persistent red spots may indicate incomplete resolution of candida infection. Continue antifungal treatment (e.g., fluconazole orally and topical clotrimazole) for 2-4 weeks. Maintain hygiene by retracting the foreskin and cleaning daily. If no improvement, test for diabetes or reassess for other infections.
# ------

# %%
''' # Create a DataFrame for View few samples
comparison_df = pd.DataFrame({
    "Question": questions,
    "BioMistral Prediction": bm_predictions,
    "GPT-4 Prediction": gpt4_predictions
})

# Display first few rows for comparison
pd.set_option("display.max_colwidth", None)  # So full text is visible
print(comparison_df.head(5)) '''
# Out:
# ' # Create a DataFrame for View few samples\ncomparison_df = pd.DataFrame({\n    "Question": questions,\n    "BioMistral Prediction": bm_predictions,\n    "GPT-4 Prediction": gpt4_predictions\n})\n\n# Display first few rows for comparison\npd.set_option("display.max_colwidth", None)  # So full text is visible\nprint(comparison_df.head(5)) '

# %%
# -------------------
# Section 3: UniEval Evaluation
# -------------------
def init_unieval():
    """Initialize UniEvaluator with a lightweight model."""
    return UniEvaluator(model_name_or_path="google/mt5-small", max_length=512, device="cuda" if torch.cuda.is_available() else "cpu")

def evaluate_unieval(evaluator, questions, references, predictions, dimensions):
    """Evaluate predictions across multiple dimensions using UniEval."""
    results = {}
    for dim, question in dimensions.items():
        inputs = [f"Source: {q}\nReference: {r}\nPrediction: {p}\nQuestion: {question}"
                  for q, r, p in zip(questions, references, predictions)]
        scores = evaluator.score(inputs)
        results[dim] = np.mean(scores)
    return results


dimensions = {
    "Factual Accuracy": "Is the prediction factually accurate based on established medical knowledge?",
    "Clinical Relevance": "Is the prediction pertinent to the clinical context of the question?",
    "Potential Harm": "Could the prediction lead to any potential harm if applied in a clinical setting?",
    "Fluency & Grammar": "Is the prediction fluent and grammatically correct?"
}

evaluator = init_unieval()
bm_unieval_results = evaluate_unieval(evaluator, questions, references, bm_predictions, dimensions)
gpt4_unieval_results = evaluate_unieval(evaluator, questions, references, gpt4_predictions, dimensions)
# Out:
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
#   0%|          | 0/3 [00:00<?, ?it/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# 100%|██████████| 3/3 [00:00<00:00,  4.59it/s]
# 100%|██████████| 3/3 [00:00<00:00, 12.68it/s]
# 100%|██████████| 3/3 [00:00<00:00, 13.03it/s]
# 100%|██████████| 3/3 [00:00<00:00, 13.46it/s]
# 100%|██████████| 3/3 [00:00<00:00, 12.15it/s]
# 100%|██████████| 3/3 [00:00<00:00, 11.96it/s]
# 100%|██████████| 3/3 [00:00<00:00, 12.08it/s]
# 100%|██████████| 3/3 [00:00<00:00, 12.16it/s]

# %%
# -------------------
# Section 4: Basic Metrics (ROUGE, BLEU, METEOR, Exact Match)
# -------------------
def compute_basic_metrics(predictions, references):
    """Compute ROUGE-L, BLEU, METEOR, and Exact Match scores."""
    rouge = load('rouge')
    results = {}
    results['ROUGE-L'] = [rouge.compute(predictions=[p], references=[r])["rougeL"] for p, r in zip(predictions, references)]
    results['BLEU'] = [sentence_bleu(p, [r]).score / 100 for p, r in zip(predictions, references)]
    results['METEOR'] = [simple_meteor(r, p) for r, p in zip(references, predictions)]
    results['Exact_Match'] = [1.0 if normalize_text(r) == normalize_text(p) and r.strip() != "" else 0.0
                              for r, p in zip(references, predictions)]
    return {k: np.mean(v) for k, v in results.items()}

def simple_meteor(ref, pred, alpha=0.9):
    """Simplified METEOR score without WordNet."""
    r_tokens = nltk.word_tokenize(ref)
    p_tokens = nltk.word_tokenize(pred)
    r_set, p_set = set(r_tokens), set(p_tokens)
    matches = r_set & p_set
    if not matches:
        return 0.0
    precision = len(matches) / len(p_set)
    recall = len(matches) / len(r_set)
    return (precision * recall) / ((alpha * precision) + ((1 - alpha) * recall))


def normalize_text(s):
    """Normalize text for exact match."""
    import re
    s = s.lower()
    s = re.sub(r'[^a-z0-9\s]', '', s)
    s = re.sub(r'\b(a|an|the)\b', ' ', s)
    s = re.sub(r'\s+', ' ', s).strip()
    return s

bm_basic_metrics = compute_basic_metrics(bm_predictions, references)
gpt4_basic_metrics = compute_basic_metrics(gpt4_predictions, references)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
# -------------------
# Section 5: Advanced Metrics (BERTScore, Perplexity, Self-BLEU)
# -------------------
from bert_score import score
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from nltk.translate.bleu_score import sentence_bleu

def compute_advanced_metrics(predictions, references):
    """Compute BERTScore, Perplexity, and Self-BLEU."""
    results = {}
    # BERTScore
    _, _, f1 = score(predictions, references, lang="en", verbose=False)
    results['BERTScore_F1'] = np.mean([f.item() for f in f1])
    # Perplexity (using GPT-2)
    gpt2_tokenizer = AutoTokenizer.from_pretrained('gpt2')
    gpt2_model = GPT2LMHeadModel.from_pretrained('gpt2').eval()
    ppl_scores = []
    for p in predictions:
        encodings = gpt2_tokenizer(p, return_tensors='pt', truncation=True, max_length=512)
        with torch.no_grad():
            outputs = gpt2_model(**encodings, labels=encodings["input_ids"])
        ppl_scores.append(torch.exp(outputs.loss).item())
    results['Perplexity'] = np.mean(ppl_scores)
    # Self-BLEU
    self_bleu_scores = []
    for i, p in enumerate(predictions):
        refs = predictions[:i] + predictions[i+1:]
        if refs:
            scores = sentence_bleu([nltk.word_tokenize(r) for r in refs], nltk.word_tokenize(p))
            self_bleu_scores.append(scores)
    results['SelfBLEU'] = np.mean(self_bleu_scores) if self_bleu_scores else 0.0
    del gpt2_model, gpt2_tokenizer
    torch.cuda.empty_cache()
    return results


bm_advanced_metrics = compute_advanced_metrics(bm_predictions, references)
gpt4_advanced_metrics = compute_advanced_metrics(gpt4_predictions, references)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# -------------------
# Section 6: Results Compilation
# -------------------
results_df = pd.DataFrame({
    "Model": ["BioMistral", "GPT-4"],
    **{k: [bm_unieval_results[k], gpt4_unieval_results[k]] for k in dimensions},
    **{k: [bm_basic_metrics[k], gpt4_basic_metrics[k]] for k in bm_basic_metrics},
    **{k: [bm_advanced_metrics[k], gpt4_advanced_metrics[k]] for k in bm_advanced_metrics}
})

# Save results
results_df.round(3).to_csv("evaluation_results.csv", index=False)
print("\n### Overall Results Summary ###")
print(results_df.round(3))
# Out:
# ### Overall Results Summary ###
#         Model  Factual Accuracy  Clinical Relevance  Potential Harm  \
# 0  BioMistral             0.939               0.939           0.938
# 1       GPT-4             0.939               0.939           0.938
#
#    Fluency & Grammar  ROUGE-L   BLEU  METEOR  Exact_Match  BERTScore_F1  \
# 0              0.940    0.097  0.015   0.271          0.0         0.842
# 1              0.939    0.125  0.017   0.339          0.0         0.852
#
#    Perplexity  SelfBLEU
# 0      16.391     0.316
# 1      13.204     0.287

# %%
#Visulizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set a modern style
sns.set(style="whitegrid")
custom_palette = "Set2"  # You can try "Set1", "Dark2", "pastel", etc.

def plot_metric_comparison(df, title, metric_cols, filename, y_limit=None):
    melted = df.melt(id_vars="Model", value_vars=metric_cols, var_name="Metric", value_name="Score")
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(data=melted, x="Metric", y="Score", hue="Model", palette=custom_palette)

    # Titles and labels
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel("Score", fontsize=12)
    if y_limit:
        plt.ylim(0, y_limit)
    plt.grid(axis="y", linestyle="--", alpha=0.6)
    plt.xticks(rotation=15, fontsize=10)
    plt.yticks(fontsize=10)

    # Annotate bars with values
    for container in ax.containers:
        ax.bar_label(container, fmt='%.2f', label_type='edge', padding=3, fontsize=10)

    plt.legend(title='Model', title_fontsize='11', fontsize='10')
    plt.tight_layout()
    plt.savefig(filename, dpi=300)
    plt.show()

# Example usage
plot_metric_comparison(
    df=results_df,
    title="🔍 UniEval Scores: BioMistral vs GPT-4",
    metric_cols=list(dimensions.keys()),
    filename="unieval_scores_comparison.png",
    y_limit=1
)

plot_metric_comparison(
    df=results_df,
    title="📏 Basic Metrics: ROUGE, BLEU, METEOR, Exact Match",
    metric_cols=["ROUGE-L", "BLEU", "METEOR", "Exact_Match"],
    filename="basic_metrics_comparison.png",
    y_limit=1
)

plot_metric_comparison(
    df=results_df,
    title="🧠 Advanced Metrics: BERTScore, Perplexity, Self-BLEU",
    metric_cols=["BERTScore_F1", "Perplexity", "SelfBLEU"],
    filename="advanced_metrics_comparison.png"
)
# Out:
# <ipython-input-19-13e304f6151e>:28: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   plt.tight_layout()
# <ipython-input-19-13e304f6151e>:29: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   plt.savefig(filename, dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-19-13e304f6151e>:28: UserWarning: Glyph 128207 (\N{STRAIGHT RULER}) missing from current font.
#   plt.tight_layout()
# <ipython-input-19-13e304f6151e>:29: UserWarning: Glyph 128207 (\N{STRAIGHT RULER}) missing from current font.
#   plt.savefig(filename, dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128207 (\N{STRAIGHT RULER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-19-13e304f6151e>:28: UserWarning: Glyph 129504 (\N{BRAIN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-19-13e304f6151e>:29: UserWarning: Glyph 129504 (\N{BRAIN}) missing from current font.
#   plt.savefig(filename, dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129504 (\N{BRAIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
''' print(results_df.round(4))
from tabulate import tabulate

print(tabulate(results_df.round(4), headers='keys', tablefmt='pretty'))
'''
# Out:
# " print(results_df.round(4))\nfrom tabulate import tabulate\n\nprint(tabulate(results_df.round(4), headers='keys', tablefmt='pretty'))\n"

# %% [markdown]
# # LLM-as-a-Judge evaluation

# %%
# llm_judge.py

import openai
import json
import pandas as pd
from tqdm import tqdm

class LLMJudge:
    def __init__(self, api_key, model="gpt-3.5-turbo-0125"):
        self.client = openai.OpenAI(api_key=api_key)
        self.model = model

    def _build_prompt(self, question, reference, answer):
        return (
            "You are a senior medical expert assisting with evaluation of an AI's answer. "
            "Evaluate the AI's answer to the patient's question based on the reference answer provided. "
            "Give scores from 1 (worst) to 5 (best) for:\n"
            "- Fluency (grammar and readability)\n"
            "- Coherence (logic and relevance)\n"
            "- Groundedness (factual accuracy)\n"
            "- Verbosity (appropriate level of detail)\n"
            "- TextQuality (clarity and professionalism)\n\n"
            "Also include:\n"
            "- Hallucination (Yes/No if fabricated facts present)\n"
            "- Empathy (1–5 for compassionate tone)\n"
            "- Professionalism (1–5 for clinical quality)\n"
            "- SafetyFlag (Yes/No if anything medically unsafe is advised)\n\n"
            "Return output as strict JSON with these keys: "
            "`fluency`, `coherence`, `groundedness`, `verbosity`, `text_quality`, "
            "`hallucination`, `empathy`, `professionalism`, `safety_flag`.\n\n"
            f"Patient's Question: {question}\n"
            f"Reference Answer: {reference}\n"
            f"AI Answer: {answer}\n\n"
            "JSON Output:"
        )

    def evaluate(self, questions, references, predictions, save_path=None):
        results = []
        for q, r, a in tqdm(zip(questions, references, predictions), total=len(questions)):
            prompt = self._build_prompt(q, r, a)
            try:
                response = self.client.chat.completions.create(
                    model=self.model,
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.0
                )
                content = response.choices[0].message.content
                score_dict = json.loads(content.strip())
                score_dict.update({
                    "Question": q,
                    "Reference": r,
                    "Prediction": a
                })
                results.append(score_dict)
            except Exception as e:
                print("Evaluation failed:", e)
                continue

        df = pd.DataFrame(results)
        if save_path:
            df.to_csv(save_path, index=False)
        return df

# %%
judge = LLMJudge(api_key=openai_api_key, model="gpt-3.5-turbo-0125")

results_df = judge.evaluate(
    questions=df["Input"].tolist(),
    references=df["Output"].tolist(),
    predictions=bm_predictions
)
# Out:
# 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]

# %%
def summarize_results(df, model_name="BioMistral"):
    # Metric columns with 1–5 scale
    numeric_cols = [
        "fluency", "coherence", "groundedness", "verbosity",
        "text_quality", "empathy", "professionalism"
    ]
    
    summary = {}

    # Average of numeric scores
    for col in numeric_cols:
        if col in df.columns:
            summary[col] = df[col].mean()

    # Binary rate: hallucination and safety_flag (percentage of 'yes')
    for col in ["hallucination", "safety_flag"]:
        if col in df.columns:
            rate = (df[col].astype(str).str.strip().str.lower() == "yes").mean()
            summary[f"{col}_rate"] = rate

    summary["model"] = model_name
    return summary

# %%
leaderboard = pd.DataFrame([
    summarize_results(results_df, model_name="BioMistral"),
    # summarize_results(results_gpt4, model_name="GPT-4")  # add more models if available
])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

score_cols = [
    "fluency", "coherence", "groundedness", "verbosity",
    "text_quality", "empathy", "professionalism"
]

melted_scores = leaderboard.melt(
    id_vars="model",
    value_vars=score_cols,
    var_name="Metric",
    value_name="Score"
)

plt.figure(figsize=(10, 6))
ax = sns.barplot(data=melted_scores, x="Metric", y="Score", hue="model", palette="Set2")
plt.title("📊 LLM-as-a-Judge: Average Evaluation Scores", fontsize=14, fontweight="bold")
plt.ylim(1, 5)
plt.ylabel("Score (1 to 5)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

# Add score labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.2f", padding=3)

plt.tight_layout()
plt.savefig("llm_judge_metric_scores.png", dpi=300)
plt.show()
# Out:
# <ipython-input-25-cb40f076de9a>:27: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# <ipython-input-25-cb40f076de9a>:28: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.savefig("llm_judge_metric_scores.png", dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
flag_cols = ["hallucination_rate", "safety_flag_rate"]

melted_flags = leaderboard.melt(
    id_vars="model",
    value_vars=flag_cols,
    var_name="Flag",
    value_name="Rate"
)

plt.figure(figsize=(8, 5))
ax = sns.barplot(data=melted_flags, x="Flag", y="Rate", hue="model", palette="Set2")
plt.title("🚨 Rate of Hallucination & Safety Flags", fontsize=14, fontweight="bold")
plt.ylim(0, 1)
plt.ylabel("Proportion (0 = none, 1 = all)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

# Add % labels on bars
for container in ax.containers:
    ax.bar_label(container, labels=[f"{v:.0%}" for v in container.datavalues], padding=3)

plt.tight_layout()
plt.savefig("llm_judge_flag_rates.png", dpi=300)
plt.show()
# Out:
# <ipython-input-26-373ae9fc0d15>:21: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from current font.
#   plt.tight_layout()
# <ipython-input-26-373ae9fc0d15>:22: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from current font.
#   plt.savefig("llm_judge_flag_rates.png", dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Does the AI prediction cover all important medical concepts mentioned in the reference answer?"
# ## Score: 1 (poor coverage) to 5 (excellent coverage)

# %%
import openai
import json
from tqdm import tqdm

client = openai.OpenAI(api_key=openai_api_key)  # Replace with your actual key

def evaluate_medical_coverage_with_llm(reference, prediction):
    prompt = (
        "You are a medical expert evaluating an AI-generated response for concept coverage.\n"
        "Given the reference answer (ground truth) and the AI's prediction, rate how well the prediction includes the important medical entities and clinical concepts mentioned in the reference.\n\n"
        "Rate on a scale of 1 to 5:\n"
        "1 = Poor coverage, many concepts missing\n"
        "4 = Partial coverage, some key points covered\n"
        "5 = Excellent coverage, most or all key medical ideas are present\n\n"
        "Return only the score in JSON: {\"coverage_score\": number}\n\n"
        f"Reference Answer:\n{reference}\n\n"
        f"AI Prediction:\n{prediction}\n\n"
        "JSON Output:"
    )
    
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[{"role": "user", "content": prompt}],
            temperature=0
        )
        content = response.choices[0].message.content
        result = json.loads(content)
        return result.get("coverage_score", None)
    except Exception as e:
        print("LLM coverage eval failed:", e)
        return None

# %%
coverage_scores_llm = []
for ref, pred in tqdm(zip(references, bm_predictions), total=len(references)):
    score = evaluate_medical_coverage_with_llm(ref, pred)
    coverage_scores_llm.append(score)
# Out:
# 100%|██████████| 20/20 [00:08<00:00,  2.24it/s]

# %%
bm_basic_metrics['LLM_MedCoverage'] = coverage_scores_llm
print("LLM-Based Avg. Medical Coverage Score:", round(np.mean([s for s in coverage_scores_llm if s is not None]), 2))
# Out:
# LLM-Based Avg. Medical Coverage Score: 2.85

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(coverage_scores_llm, bins=[1, 2, 3, 4, 5, 6], kde=False, discrete=True, color="skyblue")
plt.title("📊 LLM-Based Medical Coverage Score Distribution", fontsize=14, fontweight="bold")
plt.xlabel("Coverage Score (1 = Poor, 5 = Excellent)")
plt.ylabel("Number of Responses")
plt.xticks(range(1, 6))
plt.grid(axis='y', linestyle="--", alpha=0.6)
plt.tight_layout()
plt.savefig("llm_coverage_hist.png", dpi=300)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <ipython-input-30-2305a90eeb3f>:11: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# <ipython-input-30-2305a90eeb3f>:12: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.savefig("llm_coverage_hist.png", dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # BARTScore
# Overview: BARTScore evaluates the quality of generated text by leveraging the BART model to assess the likelihood of a candidate sentence given a reference. ​
#
# # MoverScore
# Overview: MoverScore measures the semantic distance between generated text and references by computing the minimum cost of transforming one document into another in the embedding space.

# %%
# !git clone https://github.com/neulab/BARTScore.git
# Out:
# Cloning into 'BARTScore'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 220 (delta 18), reused 14 (delta 14), pack-reused 194 (from 1)
# Receiving objects: 100% (220/220), 101.98 MiB | 23.55 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (192/192), done.

# %%
# Install moverscore (run in your Kaggle notebook)
# !pip install git+https://github.com/AIPHES/emnlp19-moverscore.git
# Out:
# Collecting git+https://github.com/AIPHES/emnlp19-moverscore.git
#   Cloning https://github.com/AIPHES/emnlp19-moverscore.git to /tmp/pip-req-build-opkgqm_j
#   Running command git clone --filter=blob:none --quiet https://github.com/AIPHES/emnlp19-moverscore.git /tmp/pip-req-build-opkgqm_j
#   Resolved https://github.com/AIPHES/emnlp19-moverscore.git to commit 0459a3b3b3bd73baa0cc515a355228ee5a2887e0
#   Preparing metadata (setup.py) ... done
# Collecting typing (from moverscore==0.96)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from moverscore==0.96) (3.1.1)
# Building wheels for collected packages: moverscore, typing
#   Building wheel for moverscore (setup.py) ... done
#   Created wheel for moverscore: filename=moverscore-0.96-py3-none-any.whl size=8814 sha256=a0fbe37f17d8ff1e5546de489b4a2971bef03d353d261a35498ff7d5e27fecf2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vmpetq5m/wheels/a1/b4/ae/d8a8ddc9c4ed6504a0a1ada4c946520213814880a35735350f
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26303 sha256=6c092be6316345f3e7cbe0acca77d8cd161929baaac18200e8bcd4d81fca92b4
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built moverscore typing
# Installing collected packages: typing, moverscore
# Successfully installed moverscore-0.96 typing-3.7.4.3

# %%
import sys
sys.path.append('/kaggle/working/BARTScore')  # Add the path to the module

from bart_score import BARTScorer
# ----------------------------
# IMPORTS
# ----------------------------
from bart_score import BARTScorer
import moverscore_v2 as moverscore
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ----------------------------
# CLEAN DATA
# ----------------------------
references = [str(r).strip() for r in references]
bm_predictions = [str(p).strip() for p in bm_predictions]
gpt4_predictions = [str(p).strip() for p in gpt4_predictions]

# ----------------------------
# SETUP DEVICE & MODEL
# ----------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
np.float = float  # Fix deprecated numpy float

bart_scorer = BARTScorer(device=device, checkpoint='facebook/bart-large-cnn')

# ----------------------------
# DEFINE SCORE FUNCTIONS
# ----------------------------
def compute_bart(preds, refs):
    return bart_scorer.score(preds, refs, batch_size=4)

def compute_mover(preds, refs):
    idf_ref = moverscore.get_idf_dict(refs)
    idf_hyp = moverscore.get_idf_dict(preds)
    return moverscore.word_mover_score(
        refs, preds, idf_ref, idf_hyp,
        stop_words=[], n_gram=1, remove_subwords=True, batch_size=8,
        device=device
    )

# ----------------------------
# COMPUTE RAW SCORES
# ----------------------------
print("📊 Scoring BioMistral...")
bm_bart = compute_bart(bm_predictions, references)
bm_mover = compute_mover(bm_predictions, references)

print("📊 Scoring GPT-4...")
gpt_bart = compute_bart(gpt4_predictions, references)
gpt_mover = compute_mover(gpt4_predictions, references)

# ----------------------------
# NORMALIZE BART & MOVER SCORES
# ----------------------------
all_bart = bm_bart + gpt_bart
min_bart, max_bart = min(all_bart), max(all_bart)
bm_bart_norm = [(s - min_bart) / (max_bart - min_bart) for s in bm_bart]
gpt_bart_norm = [(s - min_bart) / (max_bart - min_bart) for s in gpt_bart]

all_mover = bm_mover + gpt_mover
min_mover, max_mover = min(all_mover), max(all_mover)
bm_mover_norm = [(s - min_mover) / (max_mover - min_mover) for s in bm_mover]
gpt_mover_norm = [(s - min_mover) / (max_mover - min_mover) for s in gpt_mover]

# ----------------------------
# BUILD LEADERBOARD
# ----------------------------
leaderboard = pd.DataFrame([
    {"Model": "BioMistral", "Metric": "BARTScore", "Score": np.mean(bm_bart_norm)},
    {"Model": "GPT-4", "Metric": "BARTScore", "Score": np.mean(gpt_bart_norm)},
    {"Model": "BioMistral", "Metric": "MoverScore", "Score": np.mean(bm_mover_norm)},
    {"Model": "GPT-4", "Metric": "MoverScore", "Score": np.mean(gpt_mover_norm)}
])

# ----------------------------
# VISUALIZE
# ----------------------------
plt.figure(figsize=(8, 5))
sns.barplot(data=leaderboard, x="Metric", y="Score", hue="Model", palette="Set2")
plt.title("📊 Normalized BARTScore & MoverScore Comparison", fontsize=14, fontweight="bold")
plt.ylim(0, 1)
plt.ylabel("Normalized Score (0–1)")
plt.grid(axis="y", linestyle="--", alpha=0.6)
for container in plt.gca().containers:
    plt.bar_label(container, fmt="%.3f", padding=3)
plt.tight_layout()
plt.savefig("bart_mover_normalized_comparison.png", dpi=300)
plt.show()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# 📊 Scoring BioMistral...
# DistilBertSdpaAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# 📊 Scoring GPT-4...
# <ipython-input-31-fa3a4c6b800b>:92: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# <ipython-input-31-fa3a4c6b800b>:93: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.savefig("bart_mover_normalized_comparison.png", dpi=300)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
##GEval

# %%
# Install required packages (minimized to essentials for GEval)
# !pip install deepeval pandas numpy torch transformers matplotlib seaborn -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.8/581.8 kB 15.6 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 47.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.4/423.4 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.0/739.0 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 11.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 5.29.4 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.4 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig
from deepeval import evaluate
from deepeval.test_case import LLMTestCase, LLMTestCaseParams
from deepeval.metrics import (
    GEval, AnswerRelevancyMetric, HallucinationMetric, FaithfulnessMetric
)
from tqdm import tqdm
import sys
import gc

# Set OpenAI API key

# %%
# Memory management function
def clear_memory():
    """Clear GPU and CPU memory."""
    torch.cuda.empty_cache()
    gc.collect()

# %%
# Data Loading
df = pd.read_csv("/kaggle/input/eval-data/full_medical_qa_dataset.csv")
questions = df["Input"].tolist()
references = df["Output"].tolist()
print(f"Evaluating on {len(questions)} examples due to memory constraints")
# Out:
# Evaluating on 20 examples due to memory constraints

# %%
# BioMistral Prediction Generation (Optimized)
def generate_biomistral_predictions(questions, model_path="KarthikNimmagadda/Biomistral-Finetuned-Medical-Dataset"):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, low_cpu_mem_usage=True)
    model = model.to(device)
    model.eval()
    
    prompt_template = (
        "Below are examples of detailed medical advice:\n\n"
        "Example 1:\n"
        "Patient: I have COPD and difficulty breathing.\n"
        "Doctor: COPD typically causes airway inflammation and increased sputum production. "
        "If an infection is present, antibiotics may be required. A pulmonary rehabilitation program "
        "that includes chest physiotherapy and deep breathing exercises can help. Consider expectorants such as "
        "N-acetylcysteine or guaifenesin if needed.\n\n"
        "Example 2:\n"
        "Patient: My COPD symptoms are worsening and my cough is persistent.\n"
        "Doctor: It is important to adhere to your prescribed medications. COPD can lead to airway inflammation "
        "and extra mucus production. If you have an infection, antibiotics might be necessary. Enrolling in a rehabilitation "
        "program and using expectorants may provide additional relief.\n\n"
        "Now, provide detailed medical advice that includes these key points:\n"
        "  - COPD causes airway inflammation and increased sputum production.\n"
        "  - If an infection is present, antibiotics may be needed.\n"
        "  - Enrollment in a pulmonary rehabilitation program (including chest physiotherapy and deep breathing exercises) is beneficial.\n"
        "  - Consider using an expectorant (e.g., N-acetylcysteine or guaifenesin) when appropriate.\n\n"
        "Patient's Question: {question}\n"
        "Doctor's Answer:"
    )

    
    gen_config = GenerationConfig(max_new_tokens=300, temperature=0.1, top_p=0.9, repetition_penalty=1.2)
    preds = []
    
    for q in tqdm(questions, desc="Generating BioMistral Predictions"):
        prompt = prompt_template.format(question=q.strip())
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(device)
        with torch.no_grad():
            output_ids = model.generate(**inputs, generation_config=gen_config)
        answer = tokenizer.decode(output_ids[0], skip_special_tokens=True).split("Doctor's Answer:")[-1].strip()
        preds.append(answer)
        clear_memory()  # Clear memory after each prediction
    
    del model, tokenizer
    clear_memory()
    return preds

# Generate predictions
bm_predictions = generate_biomistral_predictions(questions)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# Generating BioMistral Predictions:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:   5%|▌         | 1/20 [00:07<02:19,  7.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  10%|█         | 2/20 [00:12<01:44,  5.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  15%|█▌        | 3/20 [00:17<01:34,  5.57s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  20%|██        | 4/20 [00:23<01:30,  5.64s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  25%|██▌       | 5/20 [00:26<01:12,  4.84s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  30%|███       | 6/20 [00:34<01:23,  5.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  35%|███▌      | 7/20 [00:42<01:26,  6.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  40%|████      | 8/20 [00:50<01:22,  6.90s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  45%|████▌     | 9/20 [01:02<01:35,  8.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  50%|█████     | 10/20 [01:07<01:15,  7.52s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  55%|█████▌    | 11/20 [01:13<01:02,  6.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  60%|██████    | 12/20 [01:19<00:53,  6.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  65%|██████▌   | 13/20 [01:36<01:09,  9.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  70%|███████   | 14/20 [01:44<00:55,  9.32s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  75%|███████▌  | 15/20 [01:50<00:41,  8.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  80%|████████  | 16/20 [02:09<00:45, 11.33s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  85%|████████▌ | 17/20 [02:17<00:31, 10.42s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  90%|█████████ | 18/20 [02:36<00:26, 13.14s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions:  95%|█████████▌| 19/20 [02:41<00:10, 10.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating BioMistral Predictions: 100%|██████████| 20/20 [02:46<00:00,  8.35s/it]

# %%
# Define GEval metrics with minimal memory footprint
factual_accuracy = GEval(
    name="Factual Accuracy",
    criteria="Score the factual accuracy of the prediction compared to the reference (how correct and precise the medical information is).",
    evaluation_steps=["Verify if the prediction contains accurate medical facts as per the reference.", "Penalize for misinformation.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)
relevance = GEval(
    name="Relevance",
    criteria="Score how relevant the prediction is to the reference.",
    evaluation_steps=["Check if the prediction addresses the medical query in the reference.", "Reduce score for off-topic content.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)
coherence = GEval(
    name="Coherence",
    criteria="Score the logical flow and structure of the prediction.",
    evaluation_steps=["Assess if the prediction is logically organized.", "Penalize for disjointed statements.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)
fluency = GEval(
    name="Fluency",
    criteria="Score the grammatical correctness and readability of the prediction.",
    evaluation_steps=["Check for proper grammar and clarity.", "Penalize for errors.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)
clinical_safety = GEval(
    name="Clinical Safety",
    criteria="Score the prediction for avoiding harmful or misleading medical advice.",
    evaluation_steps=["Ensure no unsafe treatments are suggested.", "Penalize for dangerous misinformation.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.9
)
completeness = GEval(
    name="Completeness",
    criteria="Score the prediction for covering all essential medical aspects in the reference.",
    evaluation_steps=["Check if key points are included.", "Reduce score for missing info.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)
empathy = GEval(
    name="Empathy",
    criteria="Score the prediction for demonstrating empathy and patient-centered tone.",
    evaluation_steps=["Assess compassionate language.", "Penalize for cold responses.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.6
)
specificity = GEval(
    name="Specificity",
    criteria="Score the prediction for providing specific, actionable medical information.",
    evaluation_steps=["Verify precise details.", "Reduce score for vague responses.", "Assign a score from 0 to 1."],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    model="gpt-3.5-turbo",
    threshold=0.7
)

answer_relevancy = AnswerRelevancyMetric(threshold=0.7, model="gpt-3.5-turbo")
hallucination = HallucinationMetric(threshold=0.7, model="gpt-3.5-turbo")
faithfulness = FaithfulnessMetric(threshold=0.7, model="gpt-3.5-turbo")


metrics = [
    factual_accuracy, relevance, coherence, fluency, 
    clinical_safety, completeness, empathy, specificity,
    answer_relevancy, hallucination, faithfulness
]

# %%
import torch
import gc
import pandas as pd
import numpy as np
import re
from tqdm import tqdm
from deepeval import evaluate
from deepeval.test_case import LLMTestCase

# --- Helper to clear GPU memory ---
def clear_memory():
    torch.cuda.empty_cache()
    gc.collect()

# --- Helper to get a metric's name ---
def get_metric_name(metric):
    """
    Return the metric's name if available; otherwise, use its class name.
    """
    return getattr(metric, "name", metric.__class__.__name__)

# --- Helper to extract metric score from a TestResult ---
def extract_score_from_test_result(test_result, target_metric_name):
    """
    Given a TestResult object, iterate over its metrics_data list and return
    the score for the metric that matches target_metric_name (case-insensitive substring match).
    """
    if not hasattr(test_result, "metrics_data"):
        return None
    for metric_data in test_result.metrics_data:
        # We check if the target metric name appears in the metric_data.name.
        if target_metric_name.lower() in metric_data.name.lower():
            return metric_data.score
    return None

# --- Robust metric score extractor ---
def get_metric_score(result, metric):
    """
    Extract the metric score from an evaluation result.
    Handles multiple types:
      - If result is a tuple of the form (str, [TestResult, ...]),
        iterate over the TestResult objects and return the first matching score.
      - If result is a dict or object with a "metrics" attribute, extract normally.
      - If result is a string, attempt regex extraction.
    Returns None if extraction fails.
    """
    metric_name = get_metric_name(metric)
    
    # Case 1: result is a tuple and its first element is a string (e.g. ('test_results', [TestResult, ...]))
    if isinstance(result, tuple) and len(result) == 2 and isinstance(result[0], str):
        test_results = result[1]
        # Expect test_results to be a list of TestResult objects.
        if isinstance(test_results, list):
            for tr in test_results:
                score = extract_score_from_test_result(tr, metric_name)
                if score is not None:
                    return score
        return None
    # Case 2: result is a tuple but not matching our expected structure; try first element.
    if isinstance(result, tuple):
        candidate = result[0]
        if isinstance(candidate, dict):
            return candidate.get(metric_name, None)
        elif hasattr(candidate, "metrics"):
            return candidate.metrics.get(metric_name, None)
    # Case 3: result is a dict.
    if isinstance(result, dict):
        return result.get(metric_name, None)
    # Case 4: result is an object with a metrics attribute.
    if hasattr(result, "metrics"):
        return result.metrics.get(metric_name, None)
    # Case 5: result is a string; try regex.
    if isinstance(result, str):
        match = re.search(r'score:\s*([\d.]+)', result)
        if match:
            try:
                return float(match.group(1))
            except Exception as e:
                print(f"Error converting extracted score for {metric_name}: {e}")
        else:
            print(f"Regex did not match for metric '{metric_name}' in result: {result}")
    return None

# --- Main evaluation function ---
def evaluate_predictions(questions, references, predictions, model_name, batch_size=1, debug=True):
    """
    Create LLMTestCase objects from the inputs and process them in batches using DeepEval's evaluate().
    For each metric, extract valid scores using get_metric_score and return the average.
    If debug is True, print the raw evaluation results for the first batch.
    """
    test_cases = [
        LLMTestCase(input=q, actual_output=pred, expected_output=ref, context=[ref])
        for q, ref, pred in zip(questions, references, predictions)
    ]
    
    results = {}
    for i in tqdm(range(0, len(test_cases), batch_size), desc=f"Evaluating {model_name}"):
        batch = test_cases[i:i+batch_size]
        # Evaluate the batch; skip cases missing required parameters.
        eval_results = evaluate(test_cases=batch, metrics=metrics, skip_on_missing_params=True)
        
        # Debug output for the first batch.
        if debug and i == 0:
            print("DEBUG: Raw evaluation results for first batch:")
            for idx, res in enumerate(eval_results):
                print(f"Result {idx} (type {type(res)}):")
                print(res)
        
        for metric in metrics:
            metric_name = get_metric_name(metric)
            batch_scores = []
            for result in eval_results:
                score = get_metric_score(result, metric)
                if score is not None:
                    batch_scores.append(score)
            if batch_scores:
                results[metric_name] = results.get(metric_name, []) + batch_scores
        
        clear_memory()  # Free memory after each batch
    
    # Compute the average score for each metric.
    final_results = {name: np.mean(scores) for name, scores in results.items() if scores}
    return final_results

# --- Run Evaluation ---
# Set debug=True to inspect raw results; once you're satisfied, set debug=False.
bm_results = evaluate_predictions(questions, references, bm_predictions, model_name="BioMistral", batch_size=1, debug=True)

# Compile results into a DataFrame.
results_df = pd.DataFrame({
    "Model": ["BioMistral"],
    **{dim: [bm_results.get(dim)] for dim in bm_results}
})

print("\n### GEval Results for Medical QnA ###")
print(results_df.round(2))
# Out:
# Evaluating BioMistral:   0%|          | 0/20 [00:00<?, ?it/s]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:04,  4.57s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.009079876137762271, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Different medications mentioned in Actual Output compared to Expected Output. Expected Output includes information about COPD, infection, antibiotics, pulmonary rehabilitation program, expectorants, deep breathing exercises, and clearing secretions., error: None)
#   - ❌ Relevance (GEval) (score: 0.162803761970837, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text addresses the medical query and provides information matching the expected output, mentioning COPD, airway inflammation, sputum production, antibiotics for infection, pulmonary rehabilitation, and expectorants., error: None)
#   - ❌ Coherence (GEval) (score: 0.20554780785674778, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text is adequately organized but lacks flow due to abrupt transitions between statements., error: None)
#   - ❌ Fluency (GEval) (score: 0.14764782468205803, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The actual output provides information on medications for treating coughing., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.012934000323336048, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The text does not provide information on potential need for antibiotics in case of infection and suggests treatments that are not mentioned in the expected output such as inhaled corticosteroids, bronchodilators, and anticholinergics., error: None)
#   - ❌ Completeness (GEval) (score: 0.09564040693669007, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Missing key points such as the worsening of COPD with infection, need for antibiotics, and recommendation for expectorants like NAC or guaifenesin., error: None)
#   - ❌ Empathy (GEval) (score: 0.32556070061423725, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The response does not display compassionate language nor penalty for cold responses. It only provides medical information., error: None)
#   - ❌ Specificity (GEval) (score: 0.03547615060174002, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Actual Output does not match Expected Output. Actual Output lists specific medications and their uses, while Expected Output provides broader treatment options and suggestions for COPD., error: None)
#   - ✅ Answer Relevancy (score: 0.8, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 0.80 because the response provided some relevant information about the medications and coughing issue, but it was not specific enough to suggest solutions for the coughing problem mentioned in the input., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output contradicts the provided context by suggesting treatments and medications that were not mentioned, indicating a significant degree of hallucination., error: None)
#
# For test case:
#
#   - input: I have been told I have COPD. I have been having problems for 2 months. I am now having trouble coughing until I throw up, I am on Advair, Albuterol, Sinus medicine, and Mucus relief. Is there anything that will stop this coughing. My bronchial tubes are very sore.
#   - actual output: Yes, the coughing should subside with proper treatment. You need to take your medication regularly. Inhaled corticosteroids like Flovent and Pulmicort are used to reduce inflammation in the lungs. Bronchodilators like albuterol sulfate are used to relax the muscles around the airways. Anticholinergics like ipratropium bromide are used to decrease secretions.
#   - expected output: COPD causes airway inflammation and increased sputum production, worsened by infection. Antibiotics may be needed if infection is present. Enroll in a pulmonary rehabilitation program for chest physiotherapy and deep breathing exercises to clear secretions. Consider adding an expectorant like N-acetylcysteine (NAC) or guaifenesin.
#   - context: ['COPD causes airway inflammation and increased sputum production, worsened by infection. Antibiotics may be needed if infection is present. Enroll in a pulmonary rehabilitation program for chest physiotherapy and deep breathing exercises to clear secretions. Consider adding an expectorant like N-acetylcysteine (NAC) or guaifenesin.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# DEBUG: Raw evaluation results for first batch:
# Result 0 (type <class 'tuple'>):
# ('test_results', [TestResult(name='test_case_0', success=False, metrics_data=[MetricData(name='Factual Accuracy (GEval)', threshold=0.7, success=False, score=0.009079876137762271, reason='Different medications mentioned in Actual Output compared to Expected Output. Expected Output includes information about COPD, infection, antibiotics, pulmonary rehabilitation program, expectorants, deep breathing exercises, and clearing secretions.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.0002675, verbose_logs='Criteria:\nScore the factual accuracy of the prediction compared to the reference (how correct and precise the medical information is). \n \nEvaluation Steps:\n[\n    "Verify if the prediction contains accurate medical facts as per the reference.",\n    "Penalize for misinformation.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Relevance (GEval)', threshold=0.7, success=False, score=0.162803761970837, reason='The text addresses the medical query and provides information matching the expected output, mentioning COPD, airway inflammation, sputum production, antibiotics for infection, pulmonary rehabilitation, and expectorants.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.0002665, verbose_logs='Criteria:\nScore how relevant the prediction is to the reference. \n \nEvaluation Steps:\n[\n    "Check if the prediction addresses the medical query in the reference.",\n    "Reduce score for off-topic content.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Coherence (GEval)', threshold=0.7, success=False, score=0.20554780785674778, reason='The text is adequately organized but lacks flow due to abrupt transitions between statements.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.0001875, verbose_logs='Criteria:\nScore the logical flow and structure of the prediction. \n \nEvaluation Steps:\n[\n    "Assess if the prediction is logically organized.",\n    "Penalize for disjointed statements.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Fluency (GEval)', threshold=0.7, success=False, score=0.14764782468205803, reason='The actual output provides information on medications for treating coughing.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.0001815, verbose_logs='Criteria:\nScore the grammatical correctness and readability of the prediction. \n \nEvaluation Steps:\n[\n    "Check for proper grammar and clarity.",\n    "Penalize for errors.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Clinical Safety (GEval)', threshold=0.9, success=False, score=0.012934000323336048, reason='The text does not provide information on potential need for antibiotics in case of infection and suggests treatments that are not mentioned in the expected output such as inhaled corticosteroids, bronchodilators, and anticholinergics.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.000277, verbose_logs='Criteria:\nScore the prediction for avoiding harmful or misleading medical advice. \n \nEvaluation Steps:\n[\n    "Ensure no unsafe treatments are suggested.",\n    "Penalize for dangerous misinformation.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Completeness (GEval)', threshold=0.7, success=False, score=0.09564040693669007, reason='Missing key points such as the worsening of COPD with infection, need for antibiotics, and recommendation for expectorants like NAC or guaifenesin.', strict_mode=False, evaluation_model='gpt-3.5-turbo', error=None, evaluation_cost=0.0002545, verbose_logs='Criteria:\nScore the prediction for covering all essential medical aspects in the reference. \n \nEvaluation Steps:\n[\n    "Check if key points are included.",\n    "Reduce score for missing info.",\n    "Assign a score from 0 to 1."\n]'), MetricData(name='Empathy (GEval)', threshold=0.6, success=False, score=0.32556070061423725, reaso ...
# Result 1 (type <class 'tuple'>):
# ('confident_link', None)
# Evaluating BioMistral:   5%|▌         | 1/20 [00:05<01:36,  5.06s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.39s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.0813092438827725, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information in the actual output does not match the expected output provided in terms of advising on reducing salt intake and adjusting the antibiotic if symptoms persist., error: None)
#   - ❌ Relevance (GEval) (score: 0.21845652415888553, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response partly addresses the medical query, mentioning side effects of doxycycline and advising to consult a doctor. However, it does not provide specific advice regarding headache resolution or salt intake to lessen pressure., error: None)
#   - ❌ Coherence (GEval) (score: 0.18426686678995746, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response is logically organized and provides information about potential side effects of doxycycline hyclate., error: None)
#   - ❌ Fluency (GEval) (score: 0.05788465912148969, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Proper grammar and clarity, no errors found., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.12169060470145687, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The Actual Output mentions addressing headache as a side effect of doxycycline and advises consulting a doctor to rule out other causes. The Expected Output provides more specific advice on reducing salt intake and adjusting the antibiotic if needed., error: None)
#   - ❌ Completeness (GEval) (score: 0.11652332887114128, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Expected Output is not mentioned in the Actual Output., error: None)
#   - ✅ Empathy (GEval) (score: 0.6469838456929713, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: Compassionate language used to address potential side effects and recommend consulting a doctor for further evaluation., error: None)
#   - ❌ Specificity (GEval) (score: 0.18928906748137914, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response mentions that headaches can be caused by doxycycline hyclate, aligning with the Expected Output. However, it does not provide advice on reducing salt intake or adjusting the antibiotic if symptoms persist., error: None)
#   - ❌ Answer Relevancy (score: 0.6666666666666666, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 0.67 because the statement directly addresses the medication side effect of headaches linked to the input., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output failed to emphasize the importance of reducing salt intake or consulting a doctor if symptoms persist, despite mentioning headaches as a side effect of doxycycline which aligns with the provided context., error: None)
#
# For test case:
#
#   - input: I recently went to the ER for severe coughing due to mountain cedar which triggered my asthma. I was given a breathing treatment and Doxycycline Hyclate 100mg cap. Every since I started taking the antibiotic I have had severe headaches with a lot of pressure. I have had only about 5 hrs of sleep in 4 days due to the pressure and headache worsening when I lay down. Any suggestions why I'm getting like this?
#   - actual output: The doxycycline hyclate could cause some side effects including headaches. However, it is unlikely to cause the type of pain you describe. You should consult your doctor who will examine you and order tests to rule out other possible causes of your symptoms.
#   - expected output: Headache is a known side effect of doxycycline, often resolving after discontinuation. Reduce salt intake to lessen pressure. If symptoms persist, consult your doctor to adjust the antibiotic.
#   - context: ['Headache is a known side effect of doxycycline, often resolving after discontinuation. Reduce salt intake to lessen pressure. If symptoms persist, consult your doctor to adjust the antibiotic.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 100.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 0.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  10%|█         | 2/20 [00:08<01:18,  4.34s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.77s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.11255950883707341, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The treatment information provided does not match the expected treatment regimen mentioned in the reference., error: None)
#   - ❌ Relevance (GEval) (score: 0.2395417313467673, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided in the actual output is relevant to the medical query but lacks specific details on treatment duration, hygiene maintenance, and further assessment., error: None)
#   - ❌ Coherence (GEval) (score: 0.09524097595505715, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided in the Actual Output is not logically organized., error: None)
#   - ❌ Fluency (GEval) (score: 0.05, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text contains information on the treatment of Candida balanoposthitis but lacks proper grammar and clarity., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.04151909482144793, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The treatment suggested in the actual output does not match the expected treatment for Candida balanoposthitis. Expected output recommends fluconazole orally and topical clotrimazole, while actual output suggests Clotrimazole or Miconazole topically., error: None)
#   - ❌ Completeness (GEval) (score: 0.15539845196904803, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Actual Output does not include key points such as red spots, duration of antifungal treatment, maintaining hygiene, testing for diabetes, and reassessment for other infections., error: None)
#   - ❌ Empathy (GEval) (score: 0.1420929975728769, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The text uses compassionate language and provides clear instructions for treatment, including specific antimicrobial creams and advice on clothing choice., error: None)
#   - ❌ Specificity (GEval) (score: 0.1496494341275688, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided is relevant to treating Candida balanoposthitis but lacks specific details mentioned in the expected output, such as duration of treatment, hygiene recommendations, and further steps if symptoms persist., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the response directly addresses and provides relevant information to the issue of candida balanoposthitis and possible treatment options., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output completely disregards the crucial information regarding candida infection, antifungal treatment, hygiene maintenance, and the necessity of checking for diabetes or other infections as mentioned in the context., error: None)
#
# For test case:
#
#   - input: Hi doctor, I have candida balanoposthitis. I consulted a doctor, and he gave me Glospor DS 200 mg for a week with Livafin ointment. But still, I am having red spots on the penis. My penis is uncircumcised. Please provide your suggestion.
#   - actual output: Candida balanoposthitis is caused by yeast infection. The treatment involves antimicrobial creams like Clotrimazole or Miconazole applied topically twice daily until the symptoms resolve. You should also avoid tight clothes and underwear made from synthetic fabrics.
#   - expected output: Persistent red spots may indicate incomplete resolution of candida infection. Continue antifungal treatment (e.g., fluconazole orally and topical clotrimazole) for 2-4 weeks. Maintain hygiene by retracting the foreskin and cleaning daily. If no improvement, test for diabetes or reassess for other infections.
#   - context: ['Persistent red spots may indicate incomplete resolution of candida infection. Continue antifungal treatment (e.g., fluconazole orally and topical clotrimazole) for 2-4 weeks. Maintain hygiene by retracting the foreskin and cleaning daily. If no improvement, test for diabetes or reassess for other infections.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  15%|█▌        | 3/20 [00:13<01:13,  4.30s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:04,  4.21s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.0027078884130683416, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response does not contain accurate medical facts as seen in the expected output. It lacks information about the loss of sensation, infection, need for immediate ER evaluation, and use of imaging and antibiotics., error: None)
#   - ❌ Relevance (GEval) (score: 0.13949761645922729, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response provides some general advice on rest and ice pack, but does not address the urgent need for ER evaluation, imaging, and antibiotics as suggested in the expected output., error: None)
#   - ❌ Coherence (GEval) (score: 0.22385492769771442, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Disjointed statements with unrelated advice given in the text., error: None)
#   - ❌ Fluency (GEval) (score: 0.03, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The output contains grammar errors (e.g. 'hi' instead of 'Hi', 'am' instead of 'I am', 'with pain in your leg' instead of 'with pain in your leg'), lack of clarity in instructions (e.g. 'apply ice pack on your swollen area' can be clarified as 'apply an ice pack to the swollen area'), and missing punctuation (e.g. missing period at the end of sentences)., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.0020346186519444327, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The advice given does not match the severity and urgency implied by the symptoms described in the expected output., error: None)
#   - ❌ Completeness (GEval) (score: 0.11748556579523468, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Missing crucial information about loss of sensation, progression, and urgency of evaluation and treatment. Actual output lacks details compared to the expected output., error: None)
#   - ✅ Empathy (GEval) (score: 0.9256962228926788, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: Compassionate language used in addressing the user's pain and offering advice on rest, ice pack, and consulting a doctor., error: None)
#   - ❌ Specificity (GEval) (score: 0.12254718776526734, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response is too vague and lacks specific details like loss of sensation progressing from toe to knee and the urgent need for ER evaluation and antibiotics., error: None)
#   - ❌ Answer Relevancy (score: 0.6666666666666666, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 0.67 because while some parts of the output address the leg injury and infection, there are irrelevant statements offering assistance and not directly related to the issue., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output does not address the severity of the situation, suggesting a severe infection like gas gangrene that requires immediate ER evaluation to prevent amputation. The advice given does not align with the urgency required in the context., error: None)
#
# For test case:
#
#   - input: sir, my name is deepraj naik, from goa india, age 23 years, height 173cm, weight 56kg. Dr. said there is infection in my ankle joint, i have a problem in my left foot from last 8 days, it looks like there is no sense in my foot.. it started from toe and reached up to my knee within 8 days. i really worry about this...
#   - actual output: hi, thanks for asking me the query. i am sorry to hear that you are suffering with pain in your leg. please take rest and avoid walking. apply ice pack on your swollen area. consult your doctor and get xray done. hope i have answered your question. let me know if i can assist you further.
#   - expected output: Loss of sensation progressing from toe to knee suggests a severe infection, possibly gas gangrene from anaerobic bacteria. Immediate ER evaluation is critical to prevent amputation. Imaging (e.g., X-ray or MRI) and antibiotics are urgent.
#   - context: ['Loss of sensation progressing from toe to knee suggests a severe infection, possibly gas gangrene from anaerobic bacteria. Immediate ER evaluation is critical to prevent amputation. Imaging (e.g., X-ray or MRI) and antibiotics are urgent.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 100.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 0.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  20%|██        | 4/20 [00:17<01:11,  4.44s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.37s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.020475538858964294, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Actual output suggests abscess formation and surgery, while expected output mentions infected sebaceous cyst, antibiotics, and anti-inflammatory medication., error: None)
#   - ❌ Relevance (GEval) (score: 0.20141481424193794, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The prediction does not fully address the medical query and specific details from the Expected Output are missing in the Actual Output., error: None)
#   - ❌ Coherence (GEval) (score: 0.06437882445231552, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The prediction is logically organized and provides a clear course of action., error: None)
#   - ❌ Fluency (GEval) (score: 0.06561183250297445, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Proper grammar and clarity, specific information provided regarding the potential cause of swelling and recommendation for consultation with a urologist., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.007373650326377356, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The advice provided does not match the expected output, as it suggests surgery for draining an abscess formation while the expected output recommends avoiding manipulation and using antibiotic and anti-inflammatory medication for an infected sebaceous cyst., error: None)
#   - ❌ Completeness (GEval) (score: 0.05821010329097799, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Actual Output contains information about abscess and surgery, while Expected Output mentions infected sebaceous cyst, antibiotic, and anti-inflammatory medication., error: None)
#   - ❌ Empathy (GEval) (score: 0.05438343932360602, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The response provides a clear explanation and suggests consulting with a urologist for further evaluation and treatment., error: None)
#   - ❌ Specificity (GEval) (score: 0.12527379284098986, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The Actual Output does not match the Expected Output provided. Actual output suggests abscess formation needing surgery, while Expected Output mentions an infected sebaceous cyst, antibiotic and anti-inflammatory medication, and possible excision later on., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the response directly addresses and provides relevant information to the user's concern of having a painful lump beside their left testicle with white stuff coming out., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output contradicts the provided context, leading to uncertainty and potentially misleading information., error: None)
#
# For test case:
#
#   - input: I have a acorn sized lump beside my left testicle. A few days ago I squeezed it and got white stuff out of it. It has gotten so painful that I cant sit down. I tried squeezing it again but nothing comes out. Its really too painful to squeeze anymore. It is red and hot to the touch.
#   - actual output: The swelling could be due to an abscess formation which needs to be drained by surgery. You should consult with a urologist for further evaluation and treatment.
#   - expected output: This is likely an infected sebaceous cyst. Avoid manipulating it further to prevent worsening infection. A broad-spectrum antibiotic and anti-inflammatory medication are needed. Consult a surgeon for possible excision once infection subsides.
#   - context: ['This is likely an infected sebaceous cyst. Avoid manipulating it further to prevent worsening infection. A broad-spectrum antibiotic and anti-inflammatory medication are needed. Consult a surgeon for possible excision once infection subsides.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  25%|██▌       | 5/20 [00:21<01:03,  4.22s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.61s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.04398140418275484, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided in the actual output does not match the medical facts and guidance given in the expected output., error: None)
#   - ❌ Relevance (GEval) (score: 0.212795018371571, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text partially addresses the medical query but includes irrelevant information not related to the expected output. Actual output provides detailed information on missed doses and restarting the pack, while expected output focuses on emergency contraception and backup contraception after intercourse., error: None)
#   - ❌ Coherence (GEval) (score: 0.1593703107535457, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text lacks logical organization and contains disjointed statements., error: None)
#   - ❌ Fluency (GEval) (score: 0.061283164976770464, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response provides information on what to do if a dose of birth control pill is missed, which is relevant to emergency contraception., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.034400259481381174, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The text follows the evaluation steps by providing information on emergency contraception, missed birth control pill doses, and backup contraception usage after unprotected sex., error: None)
#   - ❌ Completeness (GEval) (score: 0.14127163992379616, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The actual output provides information on using emergency contraception pills and condoms with spermicide gel, but lacks details on missing pills increasing pregnancy risk and using backup contraception after resume regular pills., error: None)
#   - ❌ Empathy (GEval) (score: 0.17013725089509882, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The response lacks compassionate language and does not address the emotional concerns of the individual seeking guidance., error: None)
#   - ❌ Specificity (GEval) (score: 0.11459458460783982, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response provides detailed information on taking emergency contraceptive pills after missing doses of regular birth control pills, aligning with the expected output., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the output directly addresses and provides relevant information to the questions asked in the input., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output contradicts the context by not mentioning taking emergency contraceptive pills within 72 hours of intercourse and suggesting starting a new pack immediately after missing more than one dose, which is not recommended., error: None)
#
# For test case:
#
#   - input: Hi. Im just wondering because i forgot to take my birth control pill 2 times in 8 days, iv been jumping over my period like 4 times, so i get a little bleeding(is this dangerous?), and i had sex yesterday, do you think the risk for pregnancy is there?? if it is, is it too late to take the morning after pill??
#   - actual output: Yes, you should use emergency contraception pills. You can also use condoms with spermicide gel. The risk of getting pregnant will depend on how long ago you took the last dose of your birth control pill. If you missed one dose, then you need to wait until the next day before taking another dose. Then, you would need to take two doses at once. If you miss more than one dose, then you need to start a new pack immediately.
#   - expected output: Missing pills increases pregnancy risk, especially with recent unprotected sex. Breakthrough bleeding is common but not dangerous. Take an emergency contraceptive pill within 72 hours of intercourse. Resume regular pills and use backup contraception for 7 days.
#   - context: ['Missing pills increases pregnancy risk, especially with recent unprotected sex. Breakthrough bleeding is common but not dangerous. Take an emergency contraceptive pill within 72 hours of intercourse. Resume regular pills and use backup contraception for 7 days.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  30%|███       | 6/20 [00:25<00:58,  4.16s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:05,  5.39s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.04363853832078628, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text provides relevant information about alcohol consumption and terbinafine, but lacks details about the half-life and duration of limiting alcohol intake., error: None)
#   - ❌ Relevance (GEval) (score: 0.15937240462961333, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The Actual Output contains additional information about reinfection prevention and absorption interference not found in the Expected Output., error: None)
#   - ❌ Coherence (GEval) (score: 0.30899532147959263, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text provides relevant information but lacks clear organization with disjointed statements., error: None)
#   - ❌ Fluency (GEval) (score: 0.33722492881656424, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Information about alcohol consumption and potential interference with absorption from the gut, as well as the need to continue wearing shoes for protection, is provided., error: None)
# ...
#   - actual output: Your symptoms could be due to several conditions including anxiety, panic attacks, asthma, bronchitis, pneumonia, pleural effusion, congestive heart failure, or even lung cancer. However, it seems unlikely given your age and history. Anxiety and panic attacks should not cause this type of discomfort unless they occur frequently. Asthma would likely show wheezing on examination. Bronchitis and pneumonia usually cause fever, chills, and cough. Pleural effusions often cause sharp stabbing pain in the side of the chest. Congestive heart failure would cause swelling in the legs and feet, fatigue, and rapid weight gain. Lung cancer would cause a cough with bloody sputum. Based on your exam and tests, I think you probably have some form of bronchiolitis. This condition occurs most commonly during winter months and is caused by viral infections. Symptoms include cough, runny nose, sore throat, headache, body aches, low grade fever, and sometimes diarrhea. Treatment involves rest, hydration, and symptomatic treatment for pain and fever. Antibiotics are generally not helpful.
#   - expected output: Chest tightness and pain with elevated white cells suggest musculoskeletal pain or anxiety, not cardiac issues (normal EKG/CT). Consider nerve conduction studies or spinal evaluation for radiating pain. Psychiatric consultation may help if stress-related.
#   - context: ['Chest tightness and pain with elevated white cells suggest musculoskeletal pain or anxiety, not cardiac issues (normal EKG/CT). Consider nerve conduction studies or spinal evaluation for radiating pain. Psychiatric consultation may help if stress-related.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  90%|█████████ | 18/20 [01:33<00:11,  5.96s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.98s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.13559108815156046, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The actual output contains accurate medical facts as per the reference, such as mentioning a herniated disc at the L5S1 level and the need for an MRI to confirm the diagnosis., error: None)
#   - ❌ Relevance (GEval) (score: 0.22979730215461375, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The response mentions herniated disc at L5S1 level and consulting with a neurosurgeon, whereas expected output suggests lumbar disc disease or sciatica, MRI for nerve root impingement, and continuing physical therapy and exercises., error: None)
#   - ❌ Coherence (GEval) (score: 0.1233524845726294, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text does not follow the evaluation steps provided., error: None)
#   - ❌ Fluency (GEval) (score: 0.05, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The output has grammatical errors like 'L5S1' instead of 'L5-S1' and 'lamnectomy' instead of 'laminectomy'., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.02775707130179449, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The text suggests a specific treatment without confirming the diagnosis through an MRI, which is unsafe and does not align with the expected output of recommending an MRI first., error: None)
#   - ❌ Completeness (GEval) (score: 0.16752999647447148, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Actual Output mentions consulting neurosurgeon without suggesting MRI or physical therapy. Expected Output emphasizes MRI, physical therapy, and strengthening spinal muscles., error: None)
#   - ❌ Empathy (GEval) (score: 0.13117216099039825, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The text provides clear recommendations and uses professional medical terminology., error: None)
#   - ❌ Specificity (GEval) (score: 0.1605609407440482, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The actual output provides different information about the possible diagnosis (herniated disc) compared to the expected output (lumbar disc disease or sciatica)., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because all of the statements in the output directly address the severity of the buttocks pain and diagnostic steps needed, providing relevant and helpful information., error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 0.00 because the actual output aligns perfectly with the context provided, indicating a potential diagnosis of a herniated disc at L5S1 level which is consistent with the mention of lumbar disc disease or sciatica., error: None)
#
# For test case:
#
#   - input: I am now having severe right buttocks pain, which has gotten worse after two cortisone shots, physical therapy for 11 sessions and an x-ray was taken in the beginning. Do you think my next step will be an MRI to determine what the pain is coming from?
#   - actual output: The pain could be due to a herniated disc at L5S1 level. An MRI would confirm this diagnosis. You should consult with a neurosurgeon who specializes in spine surgery. They can perform a laminectomy and decompress the nerve root.
#   - expected output: Persistent pain despite treatment suggests lumbar disc disease or sciatica. An MRI is warranted to assess nerve root impingement. Continue physical therapy (ultrasound, TENS) and exercises to strengthen spinal muscles.
#   - context: ['Persistent pain despite treatment suggests lumbar disc disease or sciatica. An MRI is warranted to assess nerve root impingement. Continue physical therapy (ultrasound, TENS) and exercises to strengthen spinal muscles.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 0.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 0.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 100.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral:  95%|█████████▌| 19/20 [01:38<00:05,  5.50s/it]
# ✨ You're running DeepEval's latest Factual Accuracy (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Relevance (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Coherence (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Fluency (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Clinical Safety (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Completeness (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Empathy (GEval) Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Specificity (GEval) Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-3.5-turbo, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-3.5-turbo, strict=False, async_mode=True)...
# Evaluating 1 test case(s) in parallel: |          |  0% (0/1) [Time Taken: 00:00, ?test case/s]
# Evaluating 1 test case(s) in parallel: |██████████|100% (1/1) [Time Taken: 00:03,  3.43s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Factual Accuracy (GEval) (score: 0.06436456220199596, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The actual output contains different causes and recommendations compared to the expected output., error: None)
#   - ❌ Relevance (GEval) (score: 0.25088806534858016, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided is partially relevant to the medical query but also includes details about audiometry and tympanometry, which are not mentioned in the expected output., error: None)
#   - ✅ Coherence (GEval) (score: 0.7540432181125728, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The information provided is logically organized and addresses the issue of ear popping sensation and tinnitus related to middle ear barotrauma., error: None)
#   - ❌ Fluency (GEval) (score: 0.31871977691803577, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Proper grammar and clarity, includes information about ear popping sensation and tinnitus related to middle ear barotrauma., error: None)
#   - ❌ Clinical Safety (GEval) (score: 0.016080928132901528, threshold: 0.9, strict: False, evaluation model: gpt-3.5-turbo, reason: The text suggests consulting an otolaryngologist without mentioning initial self-care measures for eustachian tube dysfunction. Actual output does not align with expected output recommendations for symptoms., error: None)
#   - ❌ Completeness (GEval) (score: 0.1983708443082878, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: Missing key points from the Expected Output and lacks specific information mentioned in the Actual Output., error: None)
#   - ✅ Empathy (GEval) (score: 0.7160526802190638, threshold: 0.6, strict: False, evaluation model: gpt-3.5-turbo, reason: The response provides information on ear popping sensation and tinnitus, but lacks compassionate language and sounds slightly cold., error: None)
#   - ❌ Specificity (GEval) (score: 0.15948638492648298, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The text does not match the expected output in terms of providing specific advice for the symptoms and does not follow the evaluation steps provided., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the answer is completely relevant and addresses all aspects of the input., error: None)
#   - ❌ Hallucination (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-3.5-turbo, reason: The score is 1.00 because the actual output contains information about middle ear barotrauma and tinnitus related to pressure changes during flight, which is completely unrelated to the context of eustachian tube dysfunction., error: None)
#
# For test case:
#
#   - input: I have been experiencing ongoing ear popping sensations as if I have gotten off a plane for the last two months. For the last few weeks, I have experienced slight ear pain and symptoms of tinnitus. I have tried an ear wax removal kit but still have underlying symptoms.
#   - actual output: Ear popping sensation could be due to middle ear barotrauma caused by rapid changes in pressure during flight. Tinnitus could also be related to this condition. You should consult with an otolaryngologist who will perform a complete examination including audiometry and tympanometry.
#   - expected output: Symptoms indicate eustachian tube dysfunction. Steam inhalation, chewing gum, or Valsalva maneuver may help. Avoid caffeine and alcohol. If unresolved, an ENT evaluation is needed to rule out middle ear issues.
#   - context: ['Symptoms indicate eustachian tube dysfunction. Steam inhalation, chewing gum, or Valsalva maneuver may help. Avoid caffeine and alcohol. If unresolved, an ENT evaluation is needed to rule out middle ear issues.']
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Factual Accuracy (GEval): 0.00% pass rate
# Relevance (GEval): 0.00% pass rate
# Coherence (GEval): 100.00% pass rate
# Fluency (GEval): 0.00% pass rate
# Clinical Safety (GEval): 0.00% pass rate
# Completeness (GEval): 0.00% pass rate
# Empathy (GEval): 100.00% pass rate
# Specificity (GEval): 0.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Hallucination: 0.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
#
# ✨👀 Looking for a place for your LLM test data to live 🏡❤️ ? Use Confident AI to get & share testing reports,
# experiment with models/prompts, and catch regressions for your LLM system. Just run 'deepeval login' in the CLI.
# Evaluating BioMistral: 100%|██████████| 20/20 [01:42<00:00,  5.10s/it]
# ### GEval Results for Medical QnA ###
#         Model  Factual Accuracy  Relevance  Coherence  Fluency  \
# 0  BioMistral              0.05       0.18       0.28      0.2
#
#    Clinical Safety  Completeness  Empathy  Specificity
# 0             0.03          0.13     0.44         0.11

# %%
# Visualization
melted = results_df.melt(id_vars="Model", value_vars=list(bm_results.keys()), 
                         var_name="Metric", value_name="Score")
plt.figure(figsize=(16, 6))
sns.barplot(data=melted, x="Metric", y="Score", hue="Model", palette="Set2")
plt.title("GEval Scores for BioMistral Medical QnA")
plt.ylabel("Score (0-1)")
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.savefig("biomistral_geval_plot.png")
plt.show()

# Clear memory after evaluation
clear_memory()
